# %% [markdown]
# Project 1 = https://www.ebi.ac.uk/pride/archive/projects/PXD002057
#
# Project 2 = https://www.ebi.ac.uk/pride/archive/projects/PXD05388
#
# Project 3 = https://www.ebi.ac.uk/pride/archive/projects/PXD003594
#
# "Canonical" search database contains only UniProt SwissProt canonical protein sequences (Uniprot version 2023_01).
#
# "trEMBL" search database includes protein isoforms and trEMBL sequences (Uniprot version 2023_01).

# %% [markdown]
# ----

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import pyteomics.auxiliary as aux
import seaborn as sns
import os, re, subprocess
from utility_functions import *

# %%
working_folder = "C:/Users/Enrico/OneDrive - UGent/run-ionbot"
# working_folder = "D:/run-ionbot"
PXDs = [
    'PXD002057-closed',
    'PXD005833-closed',
    'PXD014258-closed',
    'PXD002057.v0.11.4',
    'PXD005833.v0.11.4',
    'PXD014258.v0.11.4',
]
SEARCHES = [
    'canon',
    'trembl',
    'openprot',
]
DATASETS = pd.MultiIndex.from_product([PXDs,SEARCHES])
DATASETS
# Out:
# MultiIndex([( 'PXD002057-closed',    'canon'),
#             ( 'PXD002057-closed',   'trembl'),
#             ( 'PXD002057-closed', 'openprot'),
#             ( 'PXD005833-closed',    'canon'),
#             ( 'PXD005833-closed',   'trembl'),
#             ( 'PXD005833-closed', 'openprot'),
#             ( 'PXD014258-closed',    'canon'),
#             ( 'PXD014258-closed',   'trembl'),
#             ( 'PXD014258-closed', 'openprot'),
#             ('PXD002057.v0.11.4',    'canon'),
#             ('PXD002057.v0.11.4',   'trembl'),
#             ('PXD002057.v0.11.4', 'openprot'),
#             ('PXD005833.v0.11.4',    'canon'),
#             ('PXD005833.v0.11.4',   'trembl'),
#             ('PXD005833.v0.11.4', 'openprot'),
#             ('PXD014258.v0.11.4',    'canon'),
#             ('PXD014258.v0.11.4',   'trembl'),
#             ('PXD014258.v0.11.4', 'openprot')],
#            )

# %%
folders = {dataset_name:{search:[] for search in SEARCHES} for dataset_name in PXDs}
for dataset_name in PXDs:
    for search in SEARCHES:   
        for fld in os.scandir(os.path.join(working_folder, dataset_name, f"{dataset_name}-{search}")):
            if not fld.name.startswith('.') and os.path.isdir(fld.path): 
                folders[dataset_name][search].append(fld)
# folders

# %%
output_files = []
for dataset_name in PXDs:
    for search in SEARCHES:  
        j = len(folders[dataset_name][search])
        for i,sample_fld in enumerate(folders[dataset_name][search]):            
            # Read and preprocess the dataset
            data = pd.read_csv(os.path.join(sample_fld.path,'ionbot.first.csv'))
            print(f'({1+i}/{j})',sample_fld, data.shape)
            # num_psms = len(data)
            data.drop(columns=['q-value', 'PEP'], inplace=True)
            data.modifications = data.modifications.fillna('Unmodified')
            data = aux.target_decoy.qvalues(data,
                                            key='psm_score',
                                            reverse=True,
                                            is_decoy=(data.database == 'D'),
                                            q_label='q-value',
                                            formula=1,
                                            full_output=True)
            data.sort_values('database', ascending=False, inplace=True)
            data.unexpected_modification = data.unexpected_modification.fillna('')
            
            # Process proteins column and compute associated features
            data['proteins'] = data.proteins.apply(process_proteins)
            data['leadprot'] = data.proteins.apply(lambda x: x[0])
            data['protein_classes'] = data.proteins.apply(
                lambda lst: np.unique([classify_leadprot(p) for p in lst])
            )
            
            data['isCanonical'] = data.protein_classes.apply(is_peptide_canonical)
            data['isModified'] = data.apply(classifiy_mods, axis=1)
            
            # Apply custom subgroup filter and compute Group-walk specific columns
            data2 = custom_subgroup_filter(data)
            data2['isTarget'] = data2.database.eq('T').astype(int)
            data2['FDRGroup'] = data2.isCanonical + '_' + data2.isModified
            
            # Convert list columns to semicolon-separated strings for CSV export
            data2['proteins'] = data2.proteins.apply(lambda lst: ';'.join(lst))
            data2['protein_classes'] = data2.protein_classes.apply(lambda lst: ';'.join(lst))
            
            # Save the processed data & prepare for groupwalk
            out_fld = sample_fld.path
            IN  = os.path.join(out_fld, "group-walk-input.csv")
            OUT = os.path.join(out_fld, "group-walk-output.csv")
            data2.to_csv(IN, index=False)
            print(out_fld, data2.shape)
            # print(num_psms==len(data2))
    
            # Run Groupwalk
            print("GroupWalk run start...")
            _ = subprocess.run(['Rscript.exe', 'Run_group_walk.R', os.getcwd(), IN, OUT])
            print("GroupWalk run OK =",_.returncode==0)
            os.remove(IN)
# Out:
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-closed-canon'> (9905, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_01_hu_C1_2hr-closed-canon (9905, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-closed-canon'> (11712, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_02_hu_P1_2hr-closed-canon (11712, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-closed-canon'> (8176, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_03_hu_C2_2hr-closed-canon (8176, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-closed-canon'> (10527, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_04_hu_P2_2hr-closed-canon (10527, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-closed-canon'> (8074, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_05_hu_C3_2hr-closed-canon (8074, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-closed-canon'> (10349, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_06_hu_P3_2hr-closed-canon (10349, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-closed-trembl'> (11811, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_01_hu_C1_2hr-closed-trembl (11811, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-closed-trembl'> (13404, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_02_hu_P1_2hr-closed-trembl (13404, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-closed-trembl'> (9881, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_03_hu_C2_2hr-closed-trembl (9881, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-closed-trembl'> (12191, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_04_hu_P2_2hr-closed-trembl (12191, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-closed-trembl'> (9744, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_05_hu_C3_2hr-closed-trembl (9744, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-closed-trembl'> (11896, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-trembl\130327_o2_06_hu_P3_2hr-closed-trembl (11896, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-closed-open'> (13267, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_01_hu_C1_2hr-closed-open (13267, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-closed-open'> (14830, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_02_hu_P1_2hr-closed-open (14830, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-closed-open'> (11213, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_03_hu_C2_2hr-closed-open (11213, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-closed-open'> (13607, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_04_hu_P2_2hr-closed-open (13607, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-closed-open'> (11142, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_05_hu_C3_2hr-closed-open (11142, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-closed-open'> (13350, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-openprot\130327_o2_06_hu_P3_2hr-closed-open (13350, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-canon'> (11366, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM10-canon (11366, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-canon'> (12014, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM11-canon (12014, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-canon'> (14386, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM12-canon (14386, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-canon'> (12619, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM13-canon (12619, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-canon'> (11518, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM14-canon (11518, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-canon'> (9422, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM15-canon (9422, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-canon'> (14713, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM16-canon (14713, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-canon'> (8629, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM17-canon (8629, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-canon'> (11184, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM18-canon (11184, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-canon'> (12498, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM19-canon (12498, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-canon'> (8771, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM20-canon (8771, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-canon'> (7698, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM21-canon (7698, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-canon'> (6817, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM7-canon (6817, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-canon'> (11475, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM8-canon (11475, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-canon'> (12150, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-canon\AM9-canon (12150, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-trembl'> (13157, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM10-trembl (13157, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-trembl'> (13743, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM11-trembl (13743, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-trembl'> (16206, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM12-trembl (16206, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-trembl'> (14470, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM13-trembl (14470, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-trembl'> (13189, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM14-trembl (13189, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-trembl'> (10854, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM15-trembl (10854, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-trembl'> (16398, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM16-trembl (16398, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-trembl'> (10168, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM17-trembl (10168, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-trembl'> (13202, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM18-trembl (13202, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-trembl'> (14217, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM19-trembl (14217, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-trembl'> (10085, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM20-trembl (10085, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-trembl'> (9030, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM21-trembl (9030, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-trembl'> (7547, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM7-trembl (7547, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-trembl'> (13732, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM8-trembl (13732, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-trembl'> (13909, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-trembl\AM9-trembl (13909, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-openprot'> (15091, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM10-openprot (15091, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-openprot'> (15557, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM11-openprot (15557, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-openprot'> (17740, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM12-openprot (17740, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-openprot'> (16355, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM13-openprot (16355, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-openprot'> (14945, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM14-openprot (14945, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-openprot'> (12511, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM15-openprot (12511, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-openprot'> (17872, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM16-openprot (17872, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-openprot'> (11960, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM17-openprot (11960, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-openprot'> (15197, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM18-openprot (15197, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-openprot'> (15898, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM19-openprot (15898, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-openprot'> (11577, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM20-openprot (11577, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-openprot'> (10491, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM21-openprot (10491, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-openprot'> (8609, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM7-openprot (8609, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-openprot'> (15882, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM8-openprot (15882, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-openprot'> (15548, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-closed\PXD005833-closed-openprot\AM9-openprot (15548, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'Sample-BT474-closed-canon'> (48879, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-canon\Sample-BT474-closed-canon (48879, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'Sample-MCF-closed-canon'> (49544, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-canon\Sample-MCF-closed-canon (49544, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'SampleHela-closed-canon'> (39101, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-canon\SampleHela-closed-canon (39101, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'Sample-BT474-closed-trembl'> (55672, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-trembl\Sample-BT474-closed-trembl (55672, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'Sample-MCF-closed-trembl'> (56852, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-trembl\Sample-MCF-closed-trembl (56852, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'SampleHela-closed-trembl'> (44029, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-trembl\SampleHela-closed-trembl (44029, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'Sample-BT474-closed-open'> (62343, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-openprot\Sample-BT474-closed-open (62343, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'Sample-MCF-closed-open'> (63399, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-openprot\Sample-MCF-closed-open (63399, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'SampleHela-closed-open'> (49083, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-closed\PXD014258-closed-openprot\SampleHela-closed-open (49083, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr.mgf.gzip'> (18841, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_01_hu_C1_2hr.mgf.gzip (18841, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr.mgf.gzip'> (19903, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_02_hu_P1_2hr.mgf.gzip (19903, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr.mgf.gzip'> (16842, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_03_hu_C2_2hr.mgf.gzip (16842, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr.mgf.gzip'> (19056, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_04_hu_P2_2hr.mgf.gzip (19056, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr.mgf.gzip'> (16973, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_05_hu_C3_2hr.mgf.gzip (16973, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr.mgf.gzip'> (19109, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-canon\130327_o2_06_hu_P3_2hr.mgf.gzip (19109, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/6) <DirEntry '130327_o2_01_trembl'> (19091, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_01_trembl (19091, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_trembl'> (20111, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_02_trembl (20111, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_trembl'> (17067, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_03_trembl (17067, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_trembl'> (19230, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_04_trembl (19230, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_trembl'> (17235, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_05_trembl (17235, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_trembl'> (19285, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-trembl\130327_o2_06_trembl (19285, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-openprot'> (19845, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_01_hu_C1_2hr-openprot (19845, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-openprot'> (20742, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_02_hu_P1_2hr-openprot (20742, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-openprot'> (17895, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_03_hu_C2_2hr-openprot (17895, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-openprot'> (19956, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_04_hu_P2_2hr-openprot (19956, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-openprot'> (18123, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_05_hu_C3_2hr-openprot (18123, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-openprot'> (20035, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057.v0.11.4\PXD002057.v0.11.4-openprot\130327_o2_06_hu_P3_2hr-openprot (20035, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-canon'> (21587, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM10-canon (21587, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-canon'> (21528, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM11-canon (21528, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-canon'> (23157, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM12-canon (23157, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-canon'> (22813, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM13-canon (22813, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-canon'> (21566, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM14-canon (21566, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-canon'> (19963, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM15-canon (19963, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-canon'> (23051, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM16-canon (23051, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-canon'> (19734, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM17-canon (19734, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-canon'> (21982, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM18-canon (21982, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-canon'> (22240, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM19-canon (22240, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-canon'> (19030, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM20-canon (19030, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-canon'> (18652, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM21-canon (18652, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-canon'> (16178, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM7-canon (16178, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-canon'> (22639, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM8-canon (22639, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-canon'> (21423, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-canon\AM9-canon (21423, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-trembl'> (22338, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM10-trembl (22338, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-trembl'> (22297, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM11-trembl (22297, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-trembl'> (23775, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM12-trembl (23775, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-trembl'> (23576, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM13-trembl (23576, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-trembl'> (22336, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM14-trembl (22336, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-trembl'> (20788, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM15-trembl (20788, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-trembl'> (23572, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM16-trembl (23572, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-trembl'> (20620, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM17-trembl (20620, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-trembl'> (22798, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM18-trembl (22798, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-trembl'> (22917, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM19-trembl (22917, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-trembl'> (19947, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM20-trembl (19947, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-trembl'> (19616, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM21-trembl (19616, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-trembl'> (17196, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM7-trembl (17196, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-trembl'> (23476, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM8-trembl (23476, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-trembl'> (22113, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-trembl\AM9-trembl (22113, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/15) <DirEntry 'AM10-openprot'> (23089, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM10-openprot (23089, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/15) <DirEntry 'AM11-openprot'> (22974, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM11-openprot (22974, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/15) <DirEntry 'AM12-openprot'> (24397, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM12-openprot (24397, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/15) <DirEntry 'AM13-openprot'> (24337, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM13-openprot (24337, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/15) <DirEntry 'AM14-openprot'> (23071, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM14-openprot (23071, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/15) <DirEntry 'AM15-openprot'> (21639, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM15-openprot (21639, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (7/15) <DirEntry 'AM16-openprot'> (24169, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM16-openprot (24169, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (8/15) <DirEntry 'AM17-openprot'> (21574, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM17-openprot (21574, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (9/15) <DirEntry 'AM18-openprot'> (23552, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM18-openprot (23552, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (10/15) <DirEntry 'AM19-openprot'> (23669, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM19-openprot (23669, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (11/15) <DirEntry 'AM20-openprot'> (20813, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM20-openprot (20813, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (12/15) <DirEntry 'AM21-openprot'> (20573, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM21-openprot (20573, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (13/15) <DirEntry 'AM7-openprot'> (18165, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM7-openprot (18165, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (14/15) <DirEntry 'AM8-openprot'> (24256, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM8-openprot (24256, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (15/15) <DirEntry 'AM9-openprot'> (22766, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833.v0.11.4\PXD005833.v0.11.4-openprot\AM9-openprot (22766, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'Sample-BT474'> (84951, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-canon\Sample-BT474 (84951, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'Sample-MCF'> (84595, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-canon\Sample-MCF (84595, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'SampleHela'> (68652, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-canon\SampleHela (68652, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'ESC-HF-Sample-BT474-trEMBL'> (85476, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-trembl\ESC-HF-Sample-BT474-trEMBL (85476, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'ESC-HF-Sample-MCF-trEMBL'> (85031, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-trembl\ESC-HF-Sample-MCF-trEMBL (85031, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'ESC-HF-SampleHela-trEMBL'> (69120, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-trembl\ESC-HF-SampleHela-trEMBL (69120, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (1/3) <DirEntry 'ESC-HF-Sample-BT474-openprot'> (87220, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-openprot\ESC-HF-Sample-BT474-openprot (87220, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/3) <DirEntry 'ESC-HF-Sample-MCF-openprot'> (86579, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-openprot\ESC-HF-Sample-MCF-openprot (86579, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/3) <DirEntry 'ESC-HF-SampleHela-openprot'> (70699, 17)
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258.v0.11.4\PXD014258.v0.11.4-openprot\ESC-HF-SampleHela-openprot (70699, 24)
# GroupWalk run start...
# GroupWalk run OK = True

# %%
for dataset_name in PXDs:
    for search in SEARCHES: 
        tmp = []
        for fld in folders[dataset_name][search]:
            tmp.append(pd.read_csv(os.path.join(fld.path,"group-walk-output.csv"), low_memory=False))
        tmp = pd.concat(tmp, ignore_index=True)
        tmp.to_csv(os.path.join(working_folder, dataset_name, f'{dataset_name}-{search}',
                                f"combined-results-w-qvalues.csv.gz"),
                   index=False, compression='gzip')
        TD = tmp.database.value_counts()
        print(dataset_name, search, f"FDR={TD['D']/TD['T']:.2%}")
        del tmp
print('\nDone!')
# Out:
# PXD002057-closed canon FDR=49.92%
# PXD002057-closed trembl FDR=110.77%
# PXD002057-closed openprot FDR=111.38%
# PXD005833-closed canon FDR=23.33%
# PXD005833-closed trembl FDR=51.66%
# PXD005833-closed openprot FDR=58.26%
# PXD014258-closed canon FDR=14.20%
# PXD014258-closed trembl FDR=34.63%
# PXD014258-closed openprot FDR=42.49%
# PXD002057.v0.11.4 canon FDR=37.74%
# PXD002057.v0.11.4 trembl FDR=33.66%
# PXD002057.v0.11.4 openprot FDR=35.27%
# PXD005833.v0.11.4 canon FDR=23.61%
# PXD005833.v0.11.4 trembl FDR=44.99%
# PXD005833.v0.11.4 openprot FDR=46.93%
# PXD014258.v0.11.4 canon FDR=17.64%
# PXD014258.v0.11.4 trembl FDR=18.25%
# PXD014258.v0.11.4 openprot FDR=19.82%
#
# Done!

# %% [markdown]
# ----
