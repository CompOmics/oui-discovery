# %% [markdown]
# #### PSM-level FDR

# %% [markdown]
# Project 1 = https://www.ebi.ac.uk/pride/archive/projects/PXD002057
#
# Project 2 = https://www.ebi.ac.uk/pride/archive/projects/PXD05388
#
# Project 3 = https://www.ebi.ac.uk/pride/archive/projects/PXD003594
#
# "Canonical" search database contains only UniProt SwissProt canonical protein sequences (Uniprot version 2023_01).
#
# "trEMBL" search database includes protein isoforms and trEMBL sequences (Uniprot version 2023_01).

# %% [markdown]
# ----

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import pyteomics.auxiliary as aux
import seaborn as sns
import os, re, subprocess
from utility_functions import *

# %%
working_folder = "C:/Users/pc/OneDrive - UGent/run-ionbot"
# working_folder = "D:/run-ionbot"
PXDs = [
    'PXD002057-closed',
    # 'PXD005833-closed',
    # 'PXD014258-closed',
    # 'PXD002057.v0.11.4',
    # 'PXD005833.v0.11.4',
    # 'PXD014258.v0.11.4',
]
SEARCHES = [
    'canon',
    # 'trembl',
    # 'openprot',
]
DATASETS = pd.MultiIndex.from_product([PXDs,SEARCHES])
DATASETS
# Out:
# MultiIndex([('PXD002057-closed', 'canon')],
#            )

# %%
folders = {dataset_name:{search:[] for search in SEARCHES} for dataset_name in PXDs}
for dataset_name in PXDs:
    for search in SEARCHES:   
        for fld in os.scandir(os.path.join(working_folder, dataset_name, f"{dataset_name}-{search}")):
            if not fld.name.startswith('.') and os.path.isdir(fld.path): 
                folders[dataset_name][search].append(fld)
# folders

# %%
output_files = []
for dataset_name in PXDs:
    for search in SEARCHES:  
        j = len(folders[dataset_name][search])
        for i,sample_fld in enumerate(folders[dataset_name][search]):            
            # Read and preprocess the dataset
            data = pd.read_csv(os.path.join(sample_fld.path,'ionbot.first.csv'))
            print(f'({1+i}/{j})',sample_fld, data.shape)
            # num_psms = len(data)
            data.drop(columns=['q-value', 'PEP'], inplace=True)
            data.modifications = data.modifications.fillna('Unmodified')
            data.unexpected_modification = data.unexpected_modification.fillna('')
            data = aux.target_decoy.qvalues(data,
                                            key='psm_score',
                                            reverse=True,
                                            is_decoy=(data.database == 'D'),
                                            q_label='q-value',
                                            formula=1,
                                            full_output=True)
            data.sort_values('database', ascending=False, inplace=True)
            
            # Process proteins column and compute associated features
            data['proteins'] = data.proteins.apply(process_proteins)
            data['leadprot'] = data.proteins.apply(lambda x: x[0])
            data['protein_classes'] = data.proteins.apply(
                lambda lst: np.unique([classify_leadprot(p) for p in lst])
            )
            
            data['isCanonical'] = data.protein_classes.apply(is_peptide_canonical)
            data['isModified'] = data.apply(classifiy_mods, axis=1)
            
            # Apply custom subgroup filter and compute Group-walk specific columns
            data2 = custom_subgroup_filter(data)
            data2['isTarget'] = data2.database.eq('T').astype(int)
            data2['FDRGroup'] = data2.isCanonical #+ '_' + data2.isModified
            
            # Convert list columns to semicolon-separated strings for CSV export
            data2['proteins'] = data2.proteins.apply(lambda lst: ';'.join(lst))
            data2['protein_classes'] = data2.protein_classes.apply(lambda lst: ';'.join(lst))
            
            # Save the processed data & prepare for groupwalk
            out_fld = sample_fld.path
            IN  = os.path.join(out_fld, "group-walk-input.csv")
            OUT = os.path.join(out_fld, "group-walk-output.csv")
            data2.to_csv(IN, index=False)
            print(out_fld, data2.shape)
            # print(num_psms==len(data2))
    
            # Run Groupwalk
            print("GroupWalk run start...")
            _ = subprocess.run(['Rscript.exe', 'Run_group_walk.R', os.getcwd(), IN, OUT])
            print("GroupWalk run OK =",_.returncode==0)
            os.remove(IN)
# Out:
# (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-closed-canon'> (9905, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_01_hu_C1_2hr-closed-canon (9905, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-closed-canon'> (11712, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_02_hu_P1_2hr-closed-canon (11712, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-closed-canon'> (8176, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_03_hu_C2_2hr-closed-canon (8176, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-closed-canon'> (10527, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_04_hu_P2_2hr-closed-canon (10527, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-closed-canon'> (8074, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_05_hu_C3_2hr-closed-canon (8074, 24)
# GroupWalk run start...
# GroupWalk run OK = True
# (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-closed-canon'> (10349, 17)
# C:/Users/pc/OneDrive - UGent/run-ionbot\PXD002057-closed\PXD002057-closed-canon\130327_o2_06_hu_P3_2hr-closed-canon (10349, 24)
# GroupWalk run start...
# GroupWalk run OK = True

# %%
for dataset_name in PXDs:
    for search in SEARCHES: 
        tmp_folder = f'{dataset_name}-{search}'
        os.mkdir(f'D:/{tmp_folder}')
        tmp = []
        for fld in folders[dataset_name][search]:
            file = pd.read_csv(os.path.join(fld.path,"group-walk-output.csv"), low_memory=False)
            tmp.append(file)
            file.to_csv(f'D:/{fld.name}-groupwalk-only-class.csv.gz')
            print(f'D:/{tmp_folder}/{fld.name}-groupwalk-only-class.csv.gz')
        tmp = pd.concat(tmp, ignore_index=True)
        tmp.to_csv(os.path.join(working_folder, dataset_name, f'{dataset_name}-{search}',
                                f"combined-results-w-qvalues.csv.gz"),
                   index=False, compression='gzip')
        TD = tmp.database.value_counts()
        print(dataset_name, search, f"FDR={TD['D']/TD['T']:.2%}")
        del tmp
print('\nDone!')
# Out:
# D:/130327_o2_01_hu_C1_2hr-closed-canon-groupwalk-only-class.csv.gz
# D:/130327_o2_02_hu_P1_2hr-closed-canon-groupwalk-only-class.csv.gz
# D:/130327_o2_03_hu_C2_2hr-closed-canon-groupwalk-only-class.csv.gz
# D:/130327_o2_04_hu_P2_2hr-closed-canon-groupwalk-only-class.csv.gz
# D:/130327_o2_05_hu_C3_2hr-closed-canon-groupwalk-only-class.csv.gz
# D:/130327_o2_06_hu_P3_2hr-closed-canon-groupwalk-only-class.csv.gz
# PXD002057-closed canon FDR=49.92%
# D:/130327_o2_01_hu_C1_2hr-closed-trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_02_hu_P1_2hr-closed-trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_03_hu_C2_2hr-closed-trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_04_hu_P2_2hr-closed-trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_05_hu_C3_2hr-closed-trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_06_hu_P3_2hr-closed-trembl-groupwalk-only-class.csv.gz
# PXD002057-closed trembl FDR=110.77%
# D:/130327_o2_01_hu_C1_2hr-closed-open-groupwalk-only-class.csv.gz
# D:/130327_o2_02_hu_P1_2hr-closed-open-groupwalk-only-class.csv.gz
# D:/130327_o2_03_hu_C2_2hr-closed-open-groupwalk-only-class.csv.gz
# D:/130327_o2_04_hu_P2_2hr-closed-open-groupwalk-only-class.csv.gz
# D:/130327_o2_05_hu_C3_2hr-closed-open-groupwalk-only-class.csv.gz
# D:/130327_o2_06_hu_P3_2hr-closed-open-groupwalk-only-class.csv.gz
# PXD002057-closed openprot FDR=111.38%
# D:/AM10-canon-groupwalk-only-class.csv.gz
# D:/AM11-canon-groupwalk-only-class.csv.gz
# D:/AM12-canon-groupwalk-only-class.csv.gz
# D:/AM13-canon-groupwalk-only-class.csv.gz
# D:/AM14-canon-groupwalk-only-class.csv.gz
# D:/AM15-canon-groupwalk-only-class.csv.gz
# D:/AM16-canon-groupwalk-only-class.csv.gz
# D:/AM17-canon-groupwalk-only-class.csv.gz
# D:/AM18-canon-groupwalk-only-class.csv.gz
# D:/AM19-canon-groupwalk-only-class.csv.gz
# D:/AM20-canon-groupwalk-only-class.csv.gz
# D:/AM21-canon-groupwalk-only-class.csv.gz
# D:/AM7-canon-groupwalk-only-class.csv.gz
# D:/AM8-canon-groupwalk-only-class.csv.gz
# D:/AM9-canon-groupwalk-only-class.csv.gz
# PXD005833-closed canon FDR=23.33%
# D:/AM10-trembl-groupwalk-only-class.csv.gz
# D:/AM11-trembl-groupwalk-only-class.csv.gz
# D:/AM12-trembl-groupwalk-only-class.csv.gz
# D:/AM13-trembl-groupwalk-only-class.csv.gz
# D:/AM14-trembl-groupwalk-only-class.csv.gz
# D:/AM15-trembl-groupwalk-only-class.csv.gz
# D:/AM16-trembl-groupwalk-only-class.csv.gz
# D:/AM17-trembl-groupwalk-only-class.csv.gz
# D:/AM18-trembl-groupwalk-only-class.csv.gz
# D:/AM19-trembl-groupwalk-only-class.csv.gz
# D:/AM20-trembl-groupwalk-only-class.csv.gz
# D:/AM21-trembl-groupwalk-only-class.csv.gz
# D:/AM7-trembl-groupwalk-only-class.csv.gz
# D:/AM8-trembl-groupwalk-only-class.csv.gz
# D:/AM9-trembl-groupwalk-only-class.csv.gz
# PXD005833-closed trembl FDR=51.66%
# D:/AM10-openprot-groupwalk-only-class.csv.gz
# D:/AM11-openprot-groupwalk-only-class.csv.gz
# D:/AM12-openprot-groupwalk-only-class.csv.gz
# D:/AM13-openprot-groupwalk-only-class.csv.gz
# D:/AM14-openprot-groupwalk-only-class.csv.gz
# D:/AM15-openprot-groupwalk-only-class.csv.gz
# D:/AM16-openprot-groupwalk-only-class.csv.gz
# D:/AM17-openprot-groupwalk-only-class.csv.gz
# D:/AM18-openprot-groupwalk-only-class.csv.gz
# D:/AM19-openprot-groupwalk-only-class.csv.gz
# D:/AM20-openprot-groupwalk-only-class.csv.gz
# D:/AM21-openprot-groupwalk-only-class.csv.gz
# D:/AM7-openprot-groupwalk-only-class.csv.gz
# D:/AM8-openprot-groupwalk-only-class.csv.gz
# D:/AM9-openprot-groupwalk-only-class.csv.gz
# PXD005833-closed openprot FDR=58.26%
# D:/Sample-BT474-closed-canon-groupwalk-only-class.csv.gz
# D:/Sample-MCF-closed-canon-groupwalk-only-class.csv.gz
# D:/SampleHela-closed-canon-groupwalk-only-class.csv.gz
# PXD014258-closed canon FDR=14.20%
# D:/Sample-BT474-closed-trembl-groupwalk-only-class.csv.gz
# D:/Sample-MCF-closed-trembl-groupwalk-only-class.csv.gz
# D:/SampleHela-closed-trembl-groupwalk-only-class.csv.gz
# PXD014258-closed trembl FDR=34.63%
# D:/Sample-BT474-closed-open-groupwalk-only-class.csv.gz
# D:/Sample-MCF-closed-open-groupwalk-only-class.csv.gz
# D:/SampleHela-closed-open-groupwalk-only-class.csv.gz
# PXD014258-closed openprot FDR=42.49%
# D:/130327_o2_01_hu_C1_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# D:/130327_o2_02_hu_P1_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# D:/130327_o2_03_hu_C2_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# D:/130327_o2_04_hu_P2_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# D:/130327_o2_05_hu_C3_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# D:/130327_o2_06_hu_P3_2hr.mgf.gzip-groupwalk-only-class.csv.gz
# PXD002057.v0.11.4 canon FDR=37.74%
# D:/130327_o2_01_trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_02_trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_03_trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_04_trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_05_trembl-groupwalk-only-class.csv.gz
# D:/130327_o2_06_trembl-groupwalk-only-class.csv.gz
# PXD002057.v0.11.4 trembl FDR=33.66%
# D:/130327_o2_01_hu_C1_2hr-openprot-groupwalk-only-class.csv.gz
# D:/130327_o2_02_hu_P1_2hr-openprot-groupwalk-only-class.csv.gz
# D:/130327_o2_03_hu_C2_2hr-openprot-groupwalk-only-class.csv.gz
# D:/130327_o2_04_hu_P2_2hr-openprot-groupwalk-only-class.csv.gz
# D:/130327_o2_05_hu_C3_2hr-openprot-groupwalk-only-class.csv.gz
# D:/130327_o2_06_hu_P3_2hr-openprot-groupwalk-only-class.csv.gz
# PXD002057.v0.11.4 openprot FDR=35.27%
# D:/AM10-canon-groupwalk-only-class.csv.gz
# D:/AM11-canon-groupwalk-only-class.csv.gz
# D:/AM12-canon-groupwalk-only-class.csv.gz
# D:/AM13-canon-groupwalk-only-class.csv.gz
# D:/AM14-canon-groupwalk-only-class.csv.gz
# D:/AM15-canon-groupwalk-only-class.csv.gz
# D:/AM16-canon-groupwalk-only-class.csv.gz
# D:/AM17-canon-groupwalk-only-class.csv.gz
# D:/AM18-canon-groupwalk-only-class.csv.gz
# D:/AM19-canon-groupwalk-only-class.csv.gz
# D:/AM20-canon-groupwalk-only-class.csv.gz
# D:/AM21-canon-groupwalk-only-class.csv.gz
# D:/AM7-canon-groupwalk-only-class.csv.gz
# D:/AM8-canon-groupwalk-only-class.csv.gz
# D:/AM9-canon-groupwalk-only-class.csv.gz
# PXD005833.v0.11.4 canon FDR=23.61%
# D:/AM10-trembl-groupwalk-only-class.csv.gz
# D:/AM11-trembl-groupwalk-only-class.csv.gz
# D:/AM12-trembl-groupwalk-only-class.csv.gz
# D:/AM13-trembl-groupwalk-only-class.csv.gz
# D:/AM14-trembl-groupwalk-only-class.csv.gz
# D:/AM15-trembl-groupwalk-only-class.csv.gz
# D:/AM16-trembl-groupwalk-only-class.csv.gz
# D:/AM17-trembl-groupwalk-only-class.csv.gz
# D:/AM18-trembl-groupwalk-only-class.csv.gz
# D:/AM19-trembl-groupwalk-only-class.csv.gz
# D:/AM20-trembl-groupwalk-only-class.csv.gz
# D:/AM21-trembl-groupwalk-only-class.csv.gz
# D:/AM7-trembl-groupwalk-only-class.csv.gz
# D:/AM8-trembl-groupwalk-only-class.csv.gz
# D:/AM9-trembl-groupwalk-only-class.csv.gz
# PXD005833.v0.11.4 trembl FDR=44.99%
# D:/AM10-openprot-groupwalk-only-class.csv.gz
# D:/AM11-openprot-groupwalk-only-class.csv.gz
# D:/AM12-openprot-groupwalk-only-class.csv.gz
# D:/AM13-openprot-groupwalk-only-class.csv.gz
# D:/AM14-openprot-groupwalk-only-class.csv.gz
# D:/AM15-openprot-groupwalk-only-class.csv.gz
# D:/AM16-openprot-groupwalk-only-class.csv.gz
# D:/AM17-openprot-groupwalk-only-class.csv.gz
# D:/AM18-openprot-groupwalk-only-class.csv.gz
# D:/AM19-openprot-groupwalk-only-class.csv.gz
# D:/AM20-openprot-groupwalk-only-class.csv.gz
# D:/AM21-openprot-groupwalk-only-class.csv.gz
# D:/AM7-openprot-groupwalk-only-class.csv.gz
# D:/AM8-openprot-groupwalk-only-class.csv.gz
# D:/AM9-openprot-groupwalk-only-class.csv.gz
# PXD005833.v0.11.4 openprot FDR=46.93%
# D:/Sample-BT474-groupwalk-only-class.csv.gz
# D:/Sample-MCF-groupwalk-only-class.csv.gz
# D:/SampleHela-groupwalk-only-class.csv.gz
# PXD014258.v0.11.4 canon FDR=17.64%
# D:/ESC-HF-Sample-BT474-trEMBL-groupwalk-only-class.csv.gz
# D:/ESC-HF-Sample-MCF-trEMBL-groupwalk-only-class.csv.gz
# D:/ESC-HF-SampleHela-trEMBL-groupwalk-only-class.csv.gz
# PXD014258.v0.11.4 trembl FDR=18.25%
# D:/ESC-HF-Sample-BT474-openprot-groupwalk-only-class.csv.gz
# D:/ESC-HF-Sample-MCF-openprot-groupwalk-only-class.csv.gz
# D:/ESC-HF-SampleHela-openprot-groupwalk-only-class.csv.gz
# PXD014258.v0.11.4 openprot FDR=19.82%
#
# Done!

# %% [markdown]
# ----
