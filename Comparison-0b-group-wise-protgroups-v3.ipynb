# %% [markdown]
# ## Comparison-0-group-wise-protein-groups
#
# > sample-wise

# %%
import pandas as pd
import numpy as np
import pyteomics.auxiliary as aux
import seaborn as sns
import matplotlib.pyplot as plt
import os, re, subprocess
from utility_functions import *

# %%
DATE, project_palette
# Out:
# ('20250917',
#  {'canon': 'orangered', 'trembl': 'yellowgreen', 'openprot': 'cornflowerblue'})

# %%
import gzip, pickle
with gzip.open('custom-groupwalk-cutoffs.gz','rb') as infile:
    filters = pickle.load(infile)

# %%
working_folder = "C:/Users/Enrico/OneDrive - UGent/run-ionbot"
savefig_path = f"publication-data/{DATE}-protgroups.svg"
savefile_path = f'publication-data/{DATE}-identified-protein-groups-all-datasets.csv.gz'
PXDs = [
    'PXD002057.v0.11.4',
    'PXD005833.v0.11.4',
    'PXD014258.v0.11.4',
]
open_or_closed = 'OpenSearch'

# savefile_path = f'publication-data/{DATE}-identified-protein-groups-all-datasets-closed.csv.gz'
# savefig_path = f"publication-data/{DATE}-group-wise-protgroups-closed.svg"
# PXDs = [
#     'PXD002057-closed',
#     'PXD005833-closed',
#     'PXD014258-closed',
# ]
# open_or_closed = 'ClosedSearch'

SEARCHES = [
    'canon',
    'trembl',
    'openprot',
]
DATASETS = pd.MultiIndex.from_product([PXDs,SEARCHES])
DATASETS
# Out:
# MultiIndex([('PXD002057.v0.11.4',    'canon'),
#             ('PXD002057.v0.11.4',   'trembl'),
#             ('PXD002057.v0.11.4', 'openprot'),
#             ('PXD005833.v0.11.4',    'canon'),
#             ('PXD005833.v0.11.4',   'trembl'),
#             ('PXD005833.v0.11.4', 'openprot'),
#             ('PXD014258.v0.11.4',    'canon'),
#             ('PXD014258.v0.11.4',   'trembl'),
#             ('PXD014258.v0.11.4', 'openprot')],
#            )

# %%
folders = {search:{dataset_name:[] for dataset_name in PXDs} for search in SEARCHES}
for dataset_name in PXDs:
    for search in SEARCHES:   
        for fld in os.scandir(os.path.join(working_folder, dataset_name, f"{dataset_name}-{search}")):
            if not fld.name.startswith('.') and os.path.isdir(fld.path): 
                folders[search][dataset_name].append(fld)
# folders

# %%
output_files = []
for dataset_name in PXDs:
    for search in SEARCHES:  
        j = len(folders[search][dataset_name])
        for i,sample_fld in enumerate(folders[search][dataset_name]):
            psms = import_pep_IDs(os.path.join(sample_fld.path,'group-walk-output.csv'), 
                                  filtering='hybrid', 
                                  sample_specific_filters=filters,
                                  search=open_or_closed)
            print(dataset_name, f'({1+i}/{j})', sample_fld, psms.shape)
            
            psms.modifications = psms.modifications.fillna('')
            psms.proteins = psms.proteins.apply(lambda x: list(set(x.split(';'))))
            psms = psms[psms.proteins.apply(len)<100] # filter psms with too many interpretations (very rare)
            psms.proteins = psms.apply(lambda row: row.proteins if row.database=='T' else [f'decoy_{_}' for _ in row.proteins], axis=1)
            # psms.proteins
            
            # print(sample_fld.path)
            with open(os.path.join(sample_fld.path, "sample-protein-inference-input.pout"), 'w') as POUT:
                POUT.write('#ionbot_match_id\t#spectrum_title\t#global_q\t#PTMs\t#pep_w_charge\t#proteins\n')
                for _,row in psms[(psms.isCanonical!='Contam')&(psms.proteins.apply(len)<1000)].iterrows():
                    row2 =  [row.ionbot_match_id, row.spectrum_title, f"{row.global_q:.2e}", 
                             row.modifications, f"{row.charge}.{row.matched_peptide}"]
                    row2 += [f'>xx|{_}|placeholder' if '|' not in _ else _ for _ in row.proteins]
                    row2 =  '\t'.join(row2) + '\n'
                    POUT.write(row2)
            
            pout_file = os.path.join(sample_fld.path, "sample-protein-inference-input.pout")
            groups_file = os.path.join(sample_fld.path, "groups_Occam.tsv")
            subgroups_file = os.path.join(sample_fld.path, "subgroups_Occam.tsv")
            _ = subprocess.run(['pout2prot', '--occam', pout_file, groups_file, subgroups_file])
            print('Run pout2prot =',_.returncode==0)  
            
            psms = psms[['proteins','psm_score']].copy(deep=True)
            psms = psms.explode('proteins')
            psms.sort_values('psm_score', ascending=False, inplace=True)
            psms.drop_duplicates('proteins', inplace=True)
            
            # calculate protein groups scores
            protein_groups = pd.read_csv(groups_file, sep='\t', usecols=['protein accessions'])
            protein_groups.columns = ['proteins']
            protein_groups['psm_score'] = protein_groups.proteins.apply(lambda x: get_max_psm_score(x,psms))
            
            # label decoys
            protein_groups['isDecoy_'] = protein_groups.proteins.apply(group_is_decoy)
            protein_groups['database'] = protein_groups.isDecoy_.apply(lambda x: 'D' if list(x)[-1] else 'T')
            
            protein_groups = protein_groups[['proteins','database','psm_score']].copy(deep=True)
            protein_groups['experiment'] = sample_fld.name
            protein_groups['exp_number'] =  f'{dataset_name} exp {i+1}' #'-'.join(sample_fld.name.split('-')[:-1])
            protein_groups['PXD'] = dataset_name
            protein_groups['searchDB'] = search
            
            # recalculate q-values
            protein_groups = aux.target_decoy.qvalues(protein_groups, key='psm_score', reverse=True, 
                                                      is_decoy=protein_groups.database=='D',
                                                      q_label='q-value', formula=1, full_output=True)
            out_path = os.path.join(sample_fld.path, "sample_protein_groups_Occam.csv")
            protein_groups.to_csv(out_path, index=False)
            output_files.append(out_path)
# Out:
# PXD002057.v0.11.4 (1/6) <DirEntry '130327_o2_01_hu_C1_2hr.mgf.gzip'> (5744, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (2/6) <DirEntry '130327_o2_02_hu_P1_2hr.mgf.gzip'> (9718, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (3/6) <DirEntry '130327_o2_03_hu_C2_2hr.mgf.gzip'> (4156, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (4/6) <DirEntry '130327_o2_04_hu_P2_2hr.mgf.gzip'> (8518, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (5/6) <DirEntry '130327_o2_05_hu_C3_2hr.mgf.gzip'> (4432, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (6/6) <DirEntry '130327_o2_06_hu_P3_2hr.mgf.gzip'> (8573, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (1/6) <DirEntry '130327_o2_01_trembl'> (6484, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (2/6) <DirEntry '130327_o2_02_trembl'> (10977, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (3/6) <DirEntry '130327_o2_03_trembl'> (4843, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (4/6) <DirEntry '130327_o2_04_trembl'> (9596, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (5/6) <DirEntry '130327_o2_05_trembl'> (5082, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (6/6) <DirEntry '130327_o2_06_trembl'> (9921, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (1/6) <DirEntry '130327_o2_01_hu_C1_2hr-openprot'> (5968, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (2/6) <DirEntry '130327_o2_02_hu_P1_2hr-openprot'> (10444, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (3/6) <DirEntry '130327_o2_03_hu_C2_2hr-openprot'> (4464, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (4/6) <DirEntry '130327_o2_04_hu_P2_2hr-openprot'> (9047, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (5/6) <DirEntry '130327_o2_05_hu_C3_2hr-openprot'> (4775, 20)
# Run pout2prot: True
# PXD002057.v0.11.4 (6/6) <DirEntry '130327_o2_06_hu_P3_2hr-openprot'> (9292, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (1/15) <DirEntry 'AM10-canon'> (11603, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (2/15) <DirEntry 'AM11-canon'> (11957, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (3/15) <DirEntry 'AM12-canon'> (13334, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (4/15) <DirEntry 'AM13-canon'> (12597, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (5/15) <DirEntry 'AM14-canon'> (12714, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (6/15) <DirEntry 'AM15-canon'> (10914, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (7/15) <DirEntry 'AM16-canon'> (14391, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (8/15) <DirEntry 'AM17-canon'> (10009, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (9/15) <DirEntry 'AM18-canon'> (11228, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (10/15) <DirEntry 'AM19-canon'> (13478, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (11/15) <DirEntry 'AM20-canon'> (10384, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (12/15) <DirEntry 'AM21-canon'> (9724, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (13/15) <DirEntry 'AM7-canon'> (9194, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (14/15) <DirEntry 'AM8-canon'> (10732, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (15/15) <DirEntry 'AM9-canon'> (12377, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (1/15) <DirEntry 'AM10-trembl'> (10821, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (2/15) <DirEntry 'AM11-trembl'> (11149, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (3/15) <DirEntry 'AM12-trembl'> (12302, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (4/15) <DirEntry 'AM13-trembl'> (11608, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (5/15) <DirEntry 'AM14-trembl'> (11738, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (6/15) <DirEntry 'AM15-trembl'> (10040, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (7/15) <DirEntry 'AM16-trembl'> (13495, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (8/15) <DirEntry 'AM17-trembl'> (9196, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (9/15) <DirEntry 'AM18-trembl'> (10194, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (10/15) <DirEntry 'AM19-trembl'> (12311, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (11/15) <DirEntry 'AM20-trembl'> (9584, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (12/15) <DirEntry 'AM21-trembl'> (8813, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (13/15) <DirEntry 'AM7-trembl'> (8211, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (14/15) <DirEntry 'AM8-trembl'> (9664, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (15/15) <DirEntry 'AM9-trembl'> (11403, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (1/15) <DirEntry 'AM10-openprot'> (10384, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (2/15) <DirEntry 'AM11-openprot'> (10551, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (3/15) <DirEntry 'AM12-openprot'> (11588, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (4/15) <DirEntry 'AM13-openprot'> (11046, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (5/15) <DirEntry 'AM14-openprot'> (11076, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (6/15) <DirEntry 'AM15-openprot'> (9204, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (7/15) <DirEntry 'AM16-openprot'> (12645, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (8/15) <DirEntry 'AM17-openprot'> (8709, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (9/15) <DirEntry 'AM18-openprot'> (9824, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (10/15) <DirEntry 'AM19-openprot'> (11723, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (11/15) <DirEntry 'AM20-openprot'> (9083, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (12/15) <DirEntry 'AM21-openprot'> (8162, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (13/15) <DirEntry 'AM7-openprot'> (7766, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (14/15) <DirEntry 'AM8-openprot'> (9602, 20)
# Run pout2prot: True
# PXD005833.v0.11.4 (15/15) <DirEntry 'AM9-openprot'> (10807, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (1/3) <DirEntry 'Sample-BT474'> (47854, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (2/3) <DirEntry 'Sample-MCF'> (46716, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (3/3) <DirEntry 'SampleHela'> (36574, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (1/3) <DirEntry 'ESC-HF-Sample-BT474-trEMBL'> (47539, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (2/3) <DirEntry 'ESC-HF-Sample-MCF-trEMBL'> (46365, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (3/3) <DirEntry 'ESC-HF-SampleHela-trEMBL'> (36337, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (1/3) <DirEntry 'ESC-HF-Sample-BT474-openprot'> (43154, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (2/3) <DirEntry 'ESC-HF-Sample-MCF-openprot'> (43335, 20)
# Run pout2prot: True
# PXD014258.v0.11.4 (3/3) <DirEntry 'ESC-HF-SampleHela-openprot'> (33633, 20)
# Run pout2prot: True

# %%
            # protein_groups['FDRGroup'] = protein_groups.proteins.apply(classify_protein_group)
            # protein_groups['isTarget'] = protein_groups.database.apply(lambda x: int(x=='T'))
            # protein_groups = custom_subgroup_filter(protein_groups)

            # groupwalk_in_path  = os.path.join(sample_fld.path, "group-walk-protgroups-input.csv")
            # groupwalk_out_path = os.path.join(sample_fld.path, "group-walk-protgroups-output.csv")
            # _ = subprocess.run(['Rscript.exe', 'Run_group_walk.R',
            #                     os.getcwd(), 
            #                     groupwalk_in_path, 
            #                     groupwalk_out_path])
            # print('Run groupwalk:', _.returncode==0, '\n')
            # os.remove(groupwalk_in_path)
            # output_files.append(groupwalk_out_path)

# %% [markdown]
# -----

# %%
combo = [pd.read_csv(_) for _ in output_files]
combo = pd.concat(combo, ignore_index=True)
combo.rename(columns={'q-value':'global_qvalue','custom_q':'groupwise_qvalue','group_qval':'GroupWalk_q'}, inplace=True)
combo.to_csv(savefile_path, index=False, compression='gzip')

print('Without filtering:')
data = pd.read_csv(savefile_path)
T, D = data.database.value_counts()
print('Targets, Decoys =',[T,D],f"FDR = {D/T:.2%}")

print('After filtering:')
data_filtered = data[data.global_qvalue<.01].copy(deep=True)
T, D = data_filtered.database.value_counts()
print('Targets, Decoys =', [T,D], f"FDR = {D/T:.2%}")
# Out:
# Without filtering:
# Targets, Decoys = [127063, 8549] FDR = 6.73%
# After filtering:
# Targets, Decoys = [112451, 1092] FDR = 0.97%

# %%
tmp = 'protein groups from filtered peptides (hybrid filtering)'
combo = combo[(combo.global_qvalue<.01)&(combo.database=='T')].copy(deep=True)
combo.proteins = combo.proteins.str.split(',')
combo = combo.explode('proteins')
combo.drop_duplicates(['proteins','experiment','searchDB'], inplace=True)

sns.catplot(data=combo, kind='count', x='exp_number', hue='searchDB', aspect=2, palette=list(project_palette.values()))
plt.xticks(rotation=90)
plt.xlabel('experiment')
plt.ylabel('# identified proteins')
plt.title(f'{tmp} filtering')

plt.savefig(savefig_path, dpi=300, bbox_inches='tight')

# %%
autosave()
# Out:
# True

# %% [markdown]
# ----
