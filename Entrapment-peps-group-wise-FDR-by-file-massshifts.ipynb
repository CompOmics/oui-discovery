# %% [markdown]
# PXD002057 = "Parental SKBR3 and AZD8931-resistant SKBR3-AZDRc cell pellets (1 mg protein equivalent), **in biological triplicate** *(not fractions)*"
#
# PXD014258 = "One of the three lanes from each gel is cut into five fractions, thus producing 15 fractions in total for all the three cell lines **(3 cell lines × 5 fractions)**. The tryptic peptides from all the 15 fractions were subjected to LC–MS/MS analyses using Q Exactive HF—Orbitrap mass spectrometer."

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import pyteomics.auxiliary as aux
import seaborn as sns
import os, re, subprocess
from pyteomics import mass

# %%
def trunc(x,l=10000):
    if len(x)>l:
        return x[:l]
    else:
        return x

# %%
def classify_leadprot(x):
    if 'CONTAMINANT' in x.upper():
        return 'Contam'
    elif x.endswith('_p_target'):
        return 'Target'
    elif x.startswith('II_') or x.startswith('IP_'):
        return 'NonCanon'
        # Ensembl is canonical
    else:
        return 'Canon'

def is_peptide_canonical(x):
    '''x is the list of protein classes'''
    if np.array([_=='Contam' for _ in x]).any():
        return 'Contam'
    if np.array([_=='Target' for _ in x]).any():
        return 'Target'
    if np.array([_=='Canon' for _ in x]).any():
        return 'Canon'
    return 'NonCanon'

def classifiy_mods(row):
    if row.modifications=='Unmodified':
        return 'Unmodified'
    elif len(row.unexpected_modification)>1:
        return 'Unexpected'
    else:
        return 'Expected'

# %%
def computeFDR(targets_decoys):
    tmp = targets_decoys.value_counts()
    try:
        return tmp['D']/tmp['T']
    except:
        return 0

def compute_optimal_cutoff(data_subgroup, maxiter=20):
    upperlimit, lowerlimit, cutoff = 1, 0, 1
    targets_decoys_ = data_subgroup[data_subgroup['q-value']<cutoff].database
    global_fdr = computeFDR(targets_decoys_)
    # print(cutoff,'\t',global_fdr)
    
    iterations = 0
    while f"{global_fdr:.2%}" != '1.00%' and iterations<maxiter:
        if global_fdr>.01:
            upperlimit = cutoff
        else:
            lowerlimit = cutoff
        cutoff = np.round((upperlimit+lowerlimit)/2, 4)
        targets_decoys_ = data_subgroup[data_subgroup['q-value']<cutoff].database
        global_fdr = computeFDR(targets_decoys_)
        global_fdr = np.round(global_fdr,4)
        iterations += 1
    # print(cutoff,'\t',global_fdr)
    # print(targets_decoys_.value_counts())
    data_subgroup['custom_filter_pass'] = data_subgroup['q-value']<cutoff
    return data_subgroup.copy(deep=True)

# %%
def custom_subgroup_filter(data_):
    filtered_subgroups = []
    for (c,m),df in data_.groupby(['isCanonical','isModified']).__iter__():
        tmp = aux.target_decoy.qvalues(df, key='psm_score', reverse=True, is_decoy=df.database=='D',
                                      formula=1, full_output=True, q_label='custom_q')
        filtered_subgroups.append(tmp)

    return pd.concat(filtered_subgroups, ignore_index=True)

# %%
FDRbench_path = "D:/entrapment_db"
working_folder = "C:/Users/Enrico/OneDrive - UGent/run-ionbot"
# working_folder = "D:/run-ionbot"
PXDs = [
    # 'PXD002057-entrap-closed',
    # 'PXD005833-entrap-closed',
    # 'PXD014258-entrap-closed',
    'PXD002057-entrapment',
    'PXD005833-entrapment',
    'PXD014258-entrapment',
]
SEARCHES = [
    'Pep-Canon',
    'Pep-Trembl',
    'Pep-Open',
]

DATASETS = pd.MultiIndex.from_product([PXDs,SEARCHES])
DATASETS
# Out:
# MultiIndex([('PXD002057-entrapment',  'Pep-Canon'),
#             ('PXD002057-entrapment', 'Pep-Trembl'),
#             ('PXD002057-entrapment',   'Pep-Open'),
#             ('PXD005833-entrapment',  'Pep-Canon'),
#             ('PXD005833-entrapment', 'Pep-Trembl'),
#             ('PXD005833-entrapment',   'Pep-Open'),
#             ('PXD014258-entrapment',  'Pep-Canon'),
#             ('PXD014258-entrapment', 'Pep-Trembl'),
#             ('PXD014258-entrapment',   'Pep-Open')],
#            )

# %%
folders = {search:[] for search in SEARCHES}
for search in SEARCHES:   
    for dataset_name in PXDs:
        for fld in os.scandir(os.path.join(working_folder, dataset_name, f"{dataset_name}-{search}")):
            if not fld.name.startswith('.') and os.path.isdir(fld.path): 
                folders[search].append([dataset_name,fld])
# folders

# %%
for search in SEARCHES:
    for i,(dataset_name,sample_fld) in enumerate(folders[search]):
        print(1+i,sample_fld)
        data = pd.read_csv(os.path.join(sample_fld.path,'ionbot.first.csv'))
        data.drop(columns=['q-value','PEP'], inplace=True)
        data = aux.target_decoy.qvalues(data, key='psm_score', reverse=True, is_decoy=data.database=='D',
                                        q_label='q-value', formula=1, full_output=True)
        # data.sort_values('database', ascending=False, inplace=True)
        data.unexpected_modification = data.unexpected_modification.fillna('')
        data.modifications = data.modifications.fillna('Unmodified')
        # from "combine-ionbot-results"
        data['leadprot'] = data.proteins.apply(lambda x: re.sub(r'\|\|.*','',x))
        data['leadprot'] = data.leadprot.apply(lambda x: re.sub(r'.*\(\(','',x))
        data['leadprot'] = data.leadprot.apply(lambda x: re.sub(r'\)\).*','',x))
    
        FDRbench = pd.read_csv(os.path.join(FDRbench_path,f"FDRbench-{search}.csv.gz"),
                               usecols=['sequence','proteins'])
        # print('FDRbench shape =', FDRbench.shape)
        FDRbench.rename(columns={'sequence':'leadprot','proteins':'entrap_proteins'}, inplace=True)
    
        data = data.merge(FDRbench, on='leadprot', how='left')
        # data.merge(FDRbench, on='leadprot', how='left').to_csv("C:/Users/Enrico/Desktop/FDRbench-x-Test.csv", index=False)
        data.entrap_proteins = data.entrap_proteins.fillna('x|contaminant|x')
        
        data.proteins = data.entrap_proteins.str.split(';', regex=False)
        data.proteins = data.proteins.apply(lambda x: x[:50] if len(x)>50 else x)    
        data.proteins = data.proteins.apply(lambda x: [_.split('|')[1] for _ in x])
        data['leadprot'] = data.proteins.apply(lambda x: x[0])
        data['protein_classes'] = data.proteins.apply(lambda x: np.unique([classify_leadprot(_) for _ in x]))

        data['peptide_unmod_mass'] = data.matched_peptide.apply(lambda x: mass.calculate_mass(x))
        data['ptm_delta_mass'] = round(data.precursor_mass - data.peptide_unmod_mass)
        most_common_mass_shifts = data.ptm_delta_mass.value_counts().head(10).index
        
        data['isCanonical'] = data.protein_classes.apply(is_peptide_canonical)
        # data['isModified']  = data.apply(classifiy_mods,axis=1)
        data['isModified'] = data.ptm_delta_mass.apply(lambda x: 'Unmodified' if x==0 else 'groupA' if x in most_common_mass_shifts else 'groupB')
        
        # Adds a columns telling you if a PSM passes the custom filters or not (custom_filter_pass)
        data2 = custom_subgroup_filter(data)
        
        # prepare for Group-walk
        data2['isTarget'] = data2.database.apply(lambda x: int(x=='T'))
        data2['FDRGroup'] = data2.isCanonical + '_' + data2.isModified
        print(set(data2.FDRGroup))
        
        out_fld = sample_fld.path
        data2.to_csv(os.path.join(out_fld, "group-walk-input.csv"), index=False)
        print(out_fld, data2.shape)

        print("GroupWalk run start...")
        _ = subprocess.run(['Rscript.exe', 'Run_group_walk.R', os.getcwd(), 
                            os.path.join(out_fld, "group-walk-input.csv"), 
                            os.path.join(out_fld, "group-walk-output.csv")])
        print("GroupWalk run OK =",_.returncode==0)
# Out:
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_01_hu_C1_2hr-pep-canon (19709, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_02_hu_P1_2hr-pep-canon (20658, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_03_hu_C2_2hr-pep-canon (17843, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_04_hu_P2_2hr-pep-canon (19908, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_05_hu_C3_2hr-pep-canon (17970, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Canon\130327_o2_06_hu_P3_2hr-pep-canon (20044, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 7 <DirEntry 'AM10-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM10-pep-canon (21977, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 8 <DirEntry 'AM11-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM11-pep-canon (21958, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 9 <DirEntry 'AM12-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM12-pep-canon (23523, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 10 <DirEntry 'AM13-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM13-pep-canon (23251, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 11 <DirEntry 'AM14-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM14-pep-canon (22025, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 12 <DirEntry 'AM15-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM15-pep-canon (20424, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 13 <DirEntry 'AM16-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM16-pep-canon (23379, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 14 <DirEntry 'AM17-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM17-pep-canon (20232, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 15 <DirEntry 'AM18-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM18-pep-canon (22454, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 16 <DirEntry 'AM19-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM19-pep-canon (22631, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 17 <DirEntry 'AM20-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM20-pep-canon (19557, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 18 <DirEntry 'AM21-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM21-pep-canon (19221, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 19 <DirEntry 'AM7-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM7-pep-canon (16770, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 20 <DirEntry 'AM8-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM8-pep-canon (23116, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 21 <DirEntry 'AM9-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Canon\AM9-pep-canon (21771, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 22 <DirEntry 'Sample-BT474-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Canon\Sample-BT474-pep-canon (87333, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 23 <DirEntry 'Sample-MCF-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Canon\Sample-MCF-pep-canon (86716, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 24 <DirEntry 'SampleHela-pep-canon'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Canon\SampleHela-pep-canon (70866, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_01_hu_C1_2hr-pep-trembl (19858, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_02_hu_P1_2hr-pep-trembl (20828, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_03_hu_C2_2hr-pep-trembl (17959, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_04_hu_P2_2hr-pep-trembl (20045, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_05_hu_C3_2hr-pep-trembl (18160, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Trembl\130327_o2_06_hu_P3_2hr-pep-trembl (20176, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 7 <DirEntry 'AM10-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM10-pep-trembl (22193, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 8 <DirEntry 'AM11-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM11-pep-trembl (22172, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 9 <DirEntry 'AM12-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM12-pep-trembl (23700, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 10 <DirEntry 'AM13-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM13-pep-trembl (23466, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 11 <DirEntry 'AM14-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM14-pep-trembl (22201, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 12 <DirEntry 'AM15-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM15-pep-trembl (20590, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 13 <DirEntry 'AM16-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM16-pep-trembl (23504, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 14 <DirEntry 'AM17-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM17-pep-trembl (20470, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 15 <DirEntry 'AM18-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM18-pep-trembl (22642, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 16 <DirEntry 'AM19-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM19-pep-trembl (22835, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 17 <DirEntry 'AM20-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM20-pep-trembl (19787, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 18 <DirEntry 'AM21-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM21-pep-trembl (19453, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 19 <DirEntry 'AM7-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM7-pep-trembl (16982, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 20 <DirEntry 'AM8-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM8-pep-trembl (23326, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 21 <DirEntry 'AM9-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Trembl\AM9-pep-trembl (21964, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 22 <DirEntry 'Sample-BT474-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Trembl\Sample-BT474-pep-trembl (87647, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 23 <DirEntry 'Sample-MCF-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Trembl\Sample-MCF-pep-trembl (86949, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 24 <DirEntry 'SampleHela-pep-trembl'>
# {'Contam_groupB', 'Canon_Unmodified', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Trembl\SampleHela-pep-trembl (71160, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_01_hu_C1_2hr-pep-open (20620, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_02_hu_P1_2hr-pep-open (21471, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_03_hu_C2_2hr-pep-open (18857, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_04_hu_P2_2hr-pep-open (20776, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_05_hu_C3_2hr-pep-open (19022, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD002057-entrapment\PXD002057-entrapment-Pep-Open\130327_o2_06_hu_P3_2hr-pep-open (20906, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 7 <DirEntry 'AM10-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM10-pep-open (23042, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 8 <DirEntry 'AM11-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM11-pep-open (22948, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 9 <DirEntry 'AM12-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM12-pep-open (24361, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 10 <DirEntry 'AM13-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM13-pep-open (24308, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 11 <DirEntry 'AM14-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM14-pep-open (23056, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 12 <DirEntry 'AM15-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM15-pep-open (21555, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 13 <DirEntry 'AM16-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM16-pep-open (24113, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 14 <DirEntry 'AM17-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM17-pep-open (21498, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 15 <DirEntry 'AM18-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM18-pep-open (23535, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 16 <DirEntry 'AM19-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM19-pep-open (23625, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 17 <DirEntry 'AM20-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM20-pep-open (20771, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 18 <DirEntry 'AM21-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM21-pep-open (20553, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 19 <DirEntry 'AM7-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM7-pep-open (18148, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 20 <DirEntry 'AM8-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM8-pep-open (24183, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 21 <DirEntry 'AM9-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD005833-entrapment\PXD005833-entrapment-Pep-Open\AM9-pep-open (22692, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 22 <DirEntry 'Sample-BT474-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Open\Sample-BT474-pep-open (89462, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 23 <DirEntry 'Sample-MCF-pep-open'>
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Open\Sample-MCF-pep-open (88590, 27)
# GroupWalk run start...
# GroupWalk run OK = True
# 24 <DirEntry 'SampleHela-pep-open'>
# C:\Users\Enrico\.conda\envs\oui-discovery\Lib\site-packages\pyteomics\auxiliary\target_decoy.py:83: RuntimeWarning: divide by zero encountered in divide
#   q = tfalse / (ind - cumsum) / ratio
# {'Contam_groupB', 'NonCanon_groupB', 'Canon_Unmodified', 'NonCanon_groupA', 'Canon_groupA', 'Contam_Unmodified', 'Contam_groupA', 'Canon_groupB', 'NonCanon_Unmodified'}
# C:/Users/Enrico/OneDrive - UGent/run-ionbot\PXD014258-entrapment\PXD014258-entrapment-Pep-Open\SampleHela-pep-open (72907, 27)
# GroupWalk run start...
# GroupWalk run OK = True

# %% [markdown]
# -----

# %%
for search in SEARCHES:
    for i,(dataset_name,sample_fld) in enumerate(folders[search]):
        print(1+i,sample_fld)
        out_fld = sample_fld.path
        
        tmp = pd.read_csv(os.path.join(out_fld, "group-walk-output.csv"), low_memory=False)
        tmp.drop(columns=['is.decoy','isTarget'], inplace=True)
        tmp.rename(columns={'q.value':'global_qvalue','custom_q':'groupwise_qvalue','group_qval':'GroupWalk_q'}, inplace=True)

        os.makedirs(f"D:/{dataset_name}-{search}-mass-shifts", exist_ok=True)
        tmp.to_csv(f"D:/{dataset_name}-{search}-mass-shifts/{sample_fld.name}-group-walk-output.csv.gz", index=False, compression='gzip')
        
        # os.remove(os.path.join(out_fld, "group-walk-output.csv"))
        # os.remove(os.path.join(out_fld, "group-walk-input.csv"))
# Out:
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-canon'>
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-canon'>
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-canon'>
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-canon'>
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-canon'>
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-canon'>
# 7 <DirEntry 'AM10-pep-canon'>
# 8 <DirEntry 'AM11-pep-canon'>
# 9 <DirEntry 'AM12-pep-canon'>
# 10 <DirEntry 'AM13-pep-canon'>
# 11 <DirEntry 'AM14-pep-canon'>
# 12 <DirEntry 'AM15-pep-canon'>
# 13 <DirEntry 'AM16-pep-canon'>
# 14 <DirEntry 'AM17-pep-canon'>
# 15 <DirEntry 'AM18-pep-canon'>
# 16 <DirEntry 'AM19-pep-canon'>
# 17 <DirEntry 'AM20-pep-canon'>
# 18 <DirEntry 'AM21-pep-canon'>
# 19 <DirEntry 'AM7-pep-canon'>
# 20 <DirEntry 'AM8-pep-canon'>
# 21 <DirEntry 'AM9-pep-canon'>
# 22 <DirEntry 'Sample-BT474-pep-canon'>
# 23 <DirEntry 'Sample-MCF-pep-canon'>
# 24 <DirEntry 'SampleHela-pep-canon'>
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-trembl'>
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-trembl'>
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-trembl'>
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-trembl'>
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-trembl'>
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-trembl'>
# 7 <DirEntry 'AM10-pep-trembl'>
# 8 <DirEntry 'AM11-pep-trembl'>
# 9 <DirEntry 'AM12-pep-trembl'>
# 10 <DirEntry 'AM13-pep-trembl'>
# 11 <DirEntry 'AM14-pep-trembl'>
# 12 <DirEntry 'AM15-pep-trembl'>
# 13 <DirEntry 'AM16-pep-trembl'>
# 14 <DirEntry 'AM17-pep-trembl'>
# 15 <DirEntry 'AM18-pep-trembl'>
# 16 <DirEntry 'AM19-pep-trembl'>
# 17 <DirEntry 'AM20-pep-trembl'>
# 18 <DirEntry 'AM21-pep-trembl'>
# 19 <DirEntry 'AM7-pep-trembl'>
# 20 <DirEntry 'AM8-pep-trembl'>
# 21 <DirEntry 'AM9-pep-trembl'>
# 22 <DirEntry 'Sample-BT474-pep-trembl'>
# 23 <DirEntry 'Sample-MCF-pep-trembl'>
# 24 <DirEntry 'SampleHela-pep-trembl'>
# 1 <DirEntry '130327_o2_01_hu_C1_2hr-pep-open'>
# 2 <DirEntry '130327_o2_02_hu_P1_2hr-pep-open'>
# 3 <DirEntry '130327_o2_03_hu_C2_2hr-pep-open'>
# 4 <DirEntry '130327_o2_04_hu_P2_2hr-pep-open'>
# 5 <DirEntry '130327_o2_05_hu_C3_2hr-pep-open'>
# 6 <DirEntry '130327_o2_06_hu_P3_2hr-pep-open'>
# 7 <DirEntry 'AM10-pep-open'>
# 8 <DirEntry 'AM11-pep-open'>
# 9 <DirEntry 'AM12-pep-open'>
# 10 <DirEntry 'AM13-pep-open'>
# 11 <DirEntry 'AM14-pep-open'>
# 12 <DirEntry 'AM15-pep-open'>
# 13 <DirEntry 'AM16-pep-open'>
# 14 <DirEntry 'AM17-pep-open'>
# 15 <DirEntry 'AM18-pep-open'>
# 16 <DirEntry 'AM19-pep-open'>
# 17 <DirEntry 'AM20-pep-open'>
# 18 <DirEntry 'AM21-pep-open'>
# 19 <DirEntry 'AM7-pep-open'>
# 20 <DirEntry 'AM8-pep-open'>
# 21 <DirEntry 'AM9-pep-open'>
# 22 <DirEntry 'Sample-BT474-pep-open'>
# 23 <DirEntry 'Sample-MCF-pep-open'>
# 24 <DirEntry 'SampleHela-pep-open'>
